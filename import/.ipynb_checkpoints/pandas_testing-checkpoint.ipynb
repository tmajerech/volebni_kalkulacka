# %%
import pandas as pd
import psycopg2
import psycopg2.extras
from psycopg2.extras import RealDictCursor


connection = psycopg2.connect(
    database = 'volebnikalkulacka',
    user = 'postgres',
    password = 'root',
    )

# %%
SQL_Query = pd.read_sql_query(
'''
SELECT zkratka,vysledek
FROM psp_data_hl_poslanec AS hp 
	INNER JOIN psp_data_poslanec AS p 
	ON hp.id_poslanec = p.id_poslanec 
    
    INNER JOIN psp_data_zarazeni AS z
    ON p.id_osoba = z.id_osoba
    
    INNER JOIN psp_data_organy as o
    ON z.id_of = o.id_organ
    
    INNER JOIN psp_data_osoby as os
    ON os.id_osoba = p.id_osoba
    
WHERE hp.id_hlasovani = 67306 --konkretni jedno hlasovani
AND z.cl_funkce = 0 --clenstvi
AND z.do_o IS NULL
AND o.organ_id_organ = 172 --Aktualni volebni obdobi
AND o.id_typ_organu = 1 --Klub


''', connection)

df = pd.DataFrame(SQL_Query)

# %%
df.groupby(['zkratka', 'vysledek']).tail()
# Out:
#      zkratka vysledek
# 27      STAN        B
# 30     TOP09        B
# 33       SPD        B
# 35       SPD        A
# 37      ČSSD        A
# 38   KDU-ČSL        B
# 41      ČSSD        A
# 47   KDU-ČSL        B
# 52   KDU-ČSL        B
# 53   Nezařaz        B
# 57      STAN        B
# 61      STAN        B
# 68   Nezařaz        B
# 77   KDU-ČSL        B
# 84      ČSSD        A
# 87      KSČM        A
# 88     TOP09        B
# 92      KSČM        A
# 95    Piráti        B
# 96    Piráti        B
# 99      STAN        B
# 101   Piráti        A
# 107      ODS        B
# 109   Piráti        B
# 110     KSČM        A
# 111     ČSSD        A
# 112      ODS        B
# 113     ČSSD        A
# 119     KSČM        A
# 120   Piráti        B
# 121      ANO        A
# 122    TOP09        B
# 123    TOP09        B
# 124      ANO        A
# 125  KDU-ČSL        B
# 126      ODS        B
# 127      ANO        A
# 128      ANO        A
# 129      ODS        B
# 130      ODS        B
# 131     KSČM        A
# 132   Piráti        B
# 133      ANO        A

# %%
df['zkratka']
# Out:
# 0          ODS
# 1          ANO
# 2         KSČM
# 3          ANO
# 4          ANO
#         ...
# 180        ODS
# 181       KSČM
# 182     Piráti
# 183    KDU-ČSL
# 184        ANO
# Name: zkratka, Length: 185, dtype: object

# %%
for party in df['zkratka'].unique():
    pro_df = df.query(f'zkratka=="{party}" & vysledek == "A"')
    proti_df = df.query(f'zkratka=="{party}" & (vysledek == "B" | vysledek == "N" )').count()
    members_count = df.query(f'zkratka=="{party}"').count()
    
    pro_percentage = len(pro_df.index)/185
    proti_percentage = len(proti_df.index)/185
    print(abs(pro_percentage-proti_percentage)*100)
# Out:
# 1.0810810810810811
# 31.891891891891895
# 5.9459459459459465
# 0.5405405405405406
# 1.0810810810810811
# 3.2432432432432434
# 1.0810810810810811
# 0.5405405405405406
# 1.0810810810810811
# 1.0810810810810811

# %%
df_filtered = df.query('zkratka=="ANO" & vysledek == "A"')
df_filtered['count'].count()
# Out:
# 1
